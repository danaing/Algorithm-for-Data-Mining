# %% [markdown]
# <a href="https://colab.research.google.com/github/danaing/Algorithm-for-Data-Mining/blob/master/TF2_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size = 10
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(512, activation='relu', input_shape=(4,)),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(train_data,
                    validation_data=(valid_data),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 21ms/step - loss: 0.8070 - acc: 0.6917 - val_loss: 0.5507 - val_acc: 0.7000
#
# Epoch 00001: val_loss improved from inf to 0.55069, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3546 - acc: 0.8917 - val_loss: 0.2805 - val_acc: 0.9000
#
# Epoch 00002: val_loss improved from 0.55069 to 0.28052, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2531 - acc: 0.8917 - val_loss: 0.3241 - val_acc: 0.8667
#
# Epoch 00003: val_loss did not improve from 0.28052
# Epoch 4/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1426 - acc: 0.9417 - val_loss: 0.1750 - val_acc: 0.9333
#
# Epoch 00004: val_loss improved from 0.28052 to 0.17495, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2717 - acc: 0.8833 - val_loss: 0.1730 - val_acc: 0.9667
#
# Epoch 00005: val_loss improved from 0.17495 to 0.17297, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1075 - acc: 0.9583 - val_loss: 0.1928 - val_acc: 0.9000
#
# Epoch 00006: val_loss did not improve from 0.17297
# Epoch 7/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0738 - acc: 0.9833 - val_loss: 0.1668 - val_acc: 0.9667
#
# Epoch 00007: val_loss improved from 0.17297 to 0.16680, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0981 - acc: 0.9583 - val_loss: 0.1522 - val_acc: 0.9333
#
# Epoch 00008: val_loss improved from 0.16680 to 0.15225, saving model to my_checkpoint.ckpt
# Epoch 9/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1048 - acc: 0.9417 - val_loss: 0.1535 - val_acc: 0.9333
#
# Epoch 00009: val_loss did not improve from 0.15225
# Epoch 10/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0807 - acc: 0.9583 - val_loss: 0.1536 - val_acc: 0.9333
#
# Epoch 00010: val_loss did not improve from 0.15225
# Epoch 11/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0944 - acc: 0.9417 - val_loss: 0.1492 - val_acc: 0.9333
#
# Epoch 00011: val_loss improved from 0.15225 to 0.14919, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0982 - acc: 0.9500 - val_loss: 0.1478 - val_acc: 0.9333
#
# Epoch 00012: val_loss improved from 0.14919 to 0.14777, saving model to my_checkpoint.ckpt
# Epoch 13/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1078 - acc: 0.9500 - val_loss: 0.1563 - val_acc: 0.9333
#
# Epoch 00013: val_loss did not improve from 0.14777
# Epoch 14/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1389 - acc: 0.9500 - val_loss: 0.1880 - val_acc: 0.8667
#
# Epoch 00014: val_loss did not improve from 0.14777
# Epoch 15/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2509 - acc: 0.9000 - val_loss: 0.2042 - val_acc: 0.8667
#
# Epoch 00015: val_loss did not improve from 0.14777
# Epoch 16/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2821 - acc: 0.9000 - val_loss: 0.2302 - val_acc: 0.9000
#
# Epoch 00016: val_loss did not improve from 0.14777
# Epoch 17/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1000 - acc: 0.9833 - val_loss: 0.2342 - val_acc: 0.9000
#
# Epoch 00017: val_loss did not improve from 0.14777
# Epoch 18/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0530 - acc: 0.9917 - val_loss: 0.2435 - val_acc: 0.9000
#
# Epoch 00018: val_loss did not improve from 0.14777
# Epoch 19/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0413 - acc: 0.9917 - val_loss: 0.2285 - val_acc: 0.9333
#
# Epoch 00019: val_loss did not improve from 0.14777
# Epoch 20/20
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0413 - acc: 0.9750 - val_loss: 0.1922 - val_acc: 0.9333
#
# Epoch 00020: val_loss did not improve from 0.14777

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size = 10
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(512, activation='relu', input_shape=(4,)),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(train_data,
                    validation_data=(valid_data),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Downloading and preparing dataset iris/2.0.0 (download: 4.44 KiB, generated: Unknown size, total: 4.44 KiB) to /root/tensorflow_datasets/iris/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/iris/2.0.0.incompleteGFTG6O/iris-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# Dataset iris downloaded and prepared to /root/tensorflow_datasets/iris/2.0.0. Subsequent calls will reuse this data.
# Epoch 1/20
# 12/12 [==============================] - 1s 20ms/step - loss: 0.9239 - acc: 0.6500 - val_loss: 0.6905 - val_acc: 0.6333
#
# Epoch 00001: val_loss improved from inf to 0.69045, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5108 - acc: 0.8667 - val_loss: 0.3942 - val_acc: 0.9000
#
# Epoch 00002: val_loss improved from 0.69045 to 0.39419, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3331 - acc: 0.8750 - val_loss: 0.2829 - val_acc: 0.9000
#
# Epoch 00003: val_loss improved from 0.39419 to 0.28289, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2530 - acc: 0.9000 - val_loss: 0.3019 - val_acc: 0.8667
#
# Epoch 00004: val_loss did not improve from 0.28289
# Epoch 5/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1534 - acc: 0.9500 - val_loss: 0.1920 - val_acc: 0.9333
#
# Epoch 00005: val_loss improved from 0.28289 to 0.19205, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2717 - acc: 0.8750 - val_loss: 0.2764 - val_acc: 0.8667
#
# Epoch 00006: val_loss did not improve from 0.19205
# Epoch 7/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1359 - acc: 0.9250 - val_loss: 0.2535 - val_acc: 0.9000
#
# Epoch 00007: val_loss did not improve from 0.19205
# Epoch 8/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0873 - acc: 0.9833 - val_loss: 0.1678 - val_acc: 0.9667
#
# Epoch 00008: val_loss improved from 0.19205 to 0.16780, saving model to my_checkpoint.ckpt
# Epoch 9/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1269 - acc: 0.9333 - val_loss: 0.1597 - val_acc: 0.9667
#
# Epoch 00009: val_loss improved from 0.16780 to 0.15968, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0786 - acc: 0.9667 - val_loss: 0.1728 - val_acc: 0.9333
#
# Epoch 00010: val_loss did not improve from 0.15968
# Epoch 11/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0789 - acc: 0.9667 - val_loss: 0.1673 - val_acc: 0.9667
#
# Epoch 00011: val_loss did not improve from 0.15968
# Epoch 12/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0849 - acc: 0.9583 - val_loss: 0.1727 - val_acc: 0.9333
#
# Epoch 00012: val_loss did not improve from 0.15968
# Epoch 13/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0702 - acc: 0.9667 - val_loss: 0.1706 - val_acc: 0.9667
#
# Epoch 00013: val_loss did not improve from 0.15968
# Epoch 14/20
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0836 - acc: 0.9583 - val_loss: 0.1726 - val_acc: 0.9667
#
# Epoch 00014: val_loss did not improve from 0.15968
# Epoch 15/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0671 - acc: 0.9667 - val_loss: 0.1621 - val_acc: 0.9667
#
# Epoch 00015: val_loss did not improve from 0.15968
# Epoch 16/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0924 - acc: 0.9583 - val_loss: 0.1658 - val_acc: 0.9667
#
# Epoch 00016: val_loss did not improve from 0.15968
# Epoch 17/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0588 - acc: 0.9750 - val_loss: 0.1487 - val_acc: 0.9333
#
# Epoch 00017: val_loss improved from 0.15968 to 0.14866, saving model to my_checkpoint.ckpt
# Epoch 18/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1282 - acc: 0.9333 - val_loss: 0.1518 - val_acc: 0.9667
#
# Epoch 00018: val_loss did not improve from 0.14866
# Epoch 19/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0506 - acc: 0.9833 - val_loss: 0.1440 - val_acc: 0.9333
#
# Epoch 00019: val_loss improved from 0.14866 to 0.14397, saving model to my_checkpoint.ckpt
# Epoch 20/20
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1220 - acc: 0.9500 - val_loss: 0.1466 - val_acc: 0.9333
#
# Epoch 00020: val_loss did not improve from 0.14397

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size = 10
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(1024, activation='relu', input_shape=(4,)),
        Dense(512, activation='relu'),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                verbose=1)
    
    history = model.fit(train_data,
                    validation_data=(valid_data),
                    epochs=20,
                    callbacks=[checkpoint],
                   )
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 26ms/step - loss: 0.9547 - acc: 0.3167 - val_loss: 0.8366 - val_acc: 0.3333
#
# Epoch 00001: val_loss improved from inf to 0.83664, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8217 - acc: 0.4417 - val_loss: 0.7537 - val_acc: 0.5000
#
# Epoch 00002: val_loss improved from 0.83664 to 0.75368, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.7339 - acc: 0.4667 - val_loss: 0.7153 - val_acc: 0.4333
#
# Epoch 00003: val_loss improved from 0.75368 to 0.71526, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6169 - acc: 0.5833 - val_loss: 0.5574 - val_acc: 0.6333
#
# Epoch 00004: val_loss improved from 0.71526 to 0.55737, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5935 - acc: 0.5583 - val_loss: 0.7155 - val_acc: 0.5000
#
# Epoch 00005: val_loss did not improve from 0.55737
# Epoch 6/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4836 - acc: 0.5917 - val_loss: 0.5177 - val_acc: 0.6000
#
# Epoch 00006: val_loss improved from 0.55737 to 0.51769, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4424 - acc: 0.6250 - val_loss: 0.5986 - val_acc: 0.6000
#
# Epoch 00007: val_loss did not improve from 0.51769
# Epoch 8/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3820 - acc: 0.6083 - val_loss: 0.4965 - val_acc: 0.6000
#
# Epoch 00008: val_loss improved from 0.51769 to 0.49654, saving model to my_checkpoint.ckpt
# Epoch 9/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4074 - acc: 0.7583 - val_loss: 0.4676 - val_acc: 0.9000
#
# Epoch 00009: val_loss improved from 0.49654 to 0.46759, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2787 - acc: 0.9917 - val_loss: 0.3673 - val_acc: 0.9333
#
# Epoch 00010: val_loss improved from 0.46759 to 0.36731, saving model to my_checkpoint.ckpt
# Epoch 11/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3121 - acc: 0.9333 - val_loss: 0.3110 - val_acc: 0.9333
#
# Epoch 00011: val_loss improved from 0.36731 to 0.31104, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1211 - acc: 0.9833 - val_loss: 0.3352 - val_acc: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.31104
# Epoch 13/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0644 - acc: 0.9833 - val_loss: 0.2065 - val_acc: 0.9333
#
# Epoch 00013: val_loss improved from 0.31104 to 0.20653, saving model to my_checkpoint.ckpt
# Epoch 14/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1331 - acc: 0.9417 - val_loss: 0.2140 - val_acc: 0.9333
#
# Epoch 00014: val_loss did not improve from 0.20653
# Epoch 15/20
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0462 - acc: 0.9750 - val_loss: 0.2321 - val_acc: 0.9333
#
# Epoch 00015: val_loss did not improve from 0.20653
# Epoch 16/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0426 - acc: 0.9833 - val_loss: 0.1748 - val_acc: 0.9667
#
# Epoch 00016: val_loss improved from 0.20653 to 0.17477, saving model to my_checkpoint.ckpt
# Epoch 17/20
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0931 - acc: 0.9667 - val_loss: 0.1432 - val_acc: 0.9333
#
# Epoch 00017: val_loss improved from 0.17477 to 0.14323, saving model to my_checkpoint.ckpt
# Epoch 18/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1313 - acc: 0.9500 - val_loss: 0.1507 - val_acc: 0.9333
#
# Epoch 00018: val_loss did not improve from 0.14323
# Epoch 19/20
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1457 - acc: 0.9417 - val_loss: 0.1459 - val_acc: 0.9333
#
# Epoch 00019: val_loss did not improve from 0.14323
# Epoch 20/20
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2634 - acc: 0.8917 - val_loss: 0.1854 - val_acc: 0.9000
#
# Epoch 00020: val_loss did not improve from 0.14323
